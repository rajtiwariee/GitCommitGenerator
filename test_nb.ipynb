# %%
import numpy as np


np.random.randn(3,4)
# Out:
# array([[ 1.429481  ,  0.84542567,  1.44814839, -0.11317685],
#        [ 1.53249414,  0.04685378, -0.46556011, -0.13523211],
#        [-1.52012725, -0.8311959 ,  0.01232071,  0.31171608]])

# %%
ls
# Out:
# sample_data/
